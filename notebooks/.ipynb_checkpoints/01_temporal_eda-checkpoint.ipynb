# %% [markdown]
# # P3: Temporal Exploratory Data Analysis (EDA)
#
# Notebook ini bertujuan untuk melakukan eksplorasi data secara temporal (berbasis waktu) untuk mensimulasikan lingkungan *data stream* dan mengidentifikasi potensi *concept drift*.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Tambahkan src/ ke sys.path
sys.path.append(os.path.abspath('../src'))
from stream_utils import iter_csv

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#     self.io_loop.start()
# ...

# %% [markdown]
# ## 1. Load Dataset secara Bertahap (Chunking)
# Karena data berukuran besar, kita akan mensimulasikan pembacaan batch (contoh menggunakan Pandas) atau menggunakan generator `iter_csv` nantinya.

# %%
# Ganti dengan path dataset Anda, misalnya '../data/raw/creditcard.csv'
DATA_PATH = '../data/raw/creditcard.csv'

if os.path.exists(DATA_PATH):
    df = pd.read_csv(DATA_PATH)
    print(f"Data shape: {df.shape}")
    display(df.head())
else:
    print(f"File tidak ditemukan di {DATA_PATH}. Silakan unduh dataset dan tempatkan di folder tersebut.")
